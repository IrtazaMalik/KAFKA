# %%
import json
import pandas as pd

def process_data_in_chunks(file_path, chunk_size=10000):
    # This list will hold the current chunk of data
    chunk_data = []
    
    with open(file_path, 'r') as file:
        for i, line in enumerate(file):
            try:
                # Parse JSON data
                json_data = json.loads(line)
                chunk_data.append(json_data)
                
                # If the current chunk size reaches the chunk_size or end of file
                if len(chunk_data) >= chunk_size:
                    yield pd.DataFrame(chunk_data)
                    chunk_data = []  # Reset for the next chunk
            except json.JSONDecodeError:
                print(f"Error: Invalid JSON format on line {i}")
    
    # Yield any remaining data as the last chunk
    if chunk_data:
        yield pd.DataFrame(chunk_data)

# Example of how to use this function
for df_chunk in process_data_in_chunks('Sampled_Amazon_Meta.json'):
    print(df_chunk.head())  # Process each chunk, e.g., print, analyze, or save
# Out:
#                                             category tech1  \
# 0  [Clothing, Shoes & Jewelry, Men, Clothing, Jea...
# 1  [Clothing, Shoes & Jewelry, Women, Accessories...
# 2  [Clothing, Shoes & Jewelry, Women, Clothing, L...
# 3  [Clothing, Shoes & Jewelry, Women, Clothing, D...
# 4  [Clothing, Shoes & Jewelry, Women, Clothing, L...
#
#                                          description  \
# 0  [<b>pant size(Unit:inch)</b><br> W30(tag30) Wa...
# 1  [Feature <br> -Great quality winter scarf. <br...
# 2  [Material : Core-spun fabric silk <br> feature...
# 3  [Material : Core-spun fabric silk <br> feature...
# 4  [Material : Core-spun fabric silk <br> feature...
#
#                                                  fit  \
# 0   class="a-normal a-align-center a-spacing-smal...
# 1
# 2   class="a-normal a-align-center a-spacing-smal...
# 3   class="a-normal a-align-center a-spacing-smal...
# 4
#
#                                                title  \
# 0  QIBOE Men's Baggy Jeans Denim Sweatpants Loose...
# 1            Crazy Women's Voile Crinkle Scarf Shawl
# 2  FQQ Women Sexy Lingerie Lace Dress Sheer Babyd...
# 3  Crazy Women's Sexy Leather Backless Bodycon Cl...
# 4  FQQ Women's Sexy Lingerie Babydoll Dress Sleep...
#
#                                             also_buy  \
# 0  [B077GQQKRV, B07CBJQTF6, B07H2Z6S9J, B06Y26PZ5...
# 1  [B018YRBB80, B07FD9HWPM, B017M55DI4, B07KX6PPW...
# 2                                       [B00VBVXVPI]
# 3  [B01AHZSZ9A, B01I809NCO, B07219C7LQ, B06ZZBQMT...
# 4  [B06XY5N95G, B01LY4VKTL, B01EKRMG8C, B004SLKRY...
#
#                                                image tech2  brand  \
# 0  [https://images-na.ssl-images-amazon.com/image...        QIBOE
# 1  [https://images-na.ssl-images-amazon.com/image...        Crazy
# 2  [https://images-na.ssl-images-amazon.com/image...          FQQ
# 3  [https://images-na.ssl-images-amazon.com/image...        Crazy
# 4  [https://images-na.ssl-images-amazon.com/image...          FQQ
#
#                                              feature  \
# 0  [Denim, Zipper closure, Material: cotton, Styl...
# 1  [Material:voile, Size: 180cm x 95cm, A scarf t...
# 2  [100% Polyester, We use comfortable tissue to ...
# 3  [100% Polyester, We use comfortable tissue to ...
# 4  [100% Polyester, We use comfortable tissue to ...
#
#                                        rank  \
# 0  1,506,383 in Clothing, Shoes & Jewelry (
# 1    273,519 in Clothing, Shoes & Jewelry (
# 2  3,266,227 in Clothing, Shoes & Jewelry (
# 3    641,576 in Clothing, Shoes & Jewelry (
# 4  1,761,440 in Clothing, Shoes & Jewelry (
#
#                                            also_view details  \
# 0  [B07H2Z6S9J, B077GQQKRV, B072XTTTK9, B002DMJOC...      {}
# 1  [B017M5BVXA, B00NSF70KM, B01LYRMI0Q, B017M55DI...      {}
# 2                                                 []      {}
# 3  [B074XSR8LC, B01MZITI8H, B07JMZDG8C, B01LY4VKT...      {}
# 4  [B00UHFS00K, B01EKRMG8C, B01AHZSZ9A, B06XY5N95...      {}
#
#                                             main_cat similar_item  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#                                                 date   price        asin
# 0  <div class="a-fixed-left-grid a-spacing-none">...  $38.99  6342509379
# 1  <div class="a-fixed-left-grid a-spacing-none">...   $0.50  6342502315
# 2  <div class="a-fixed-left-grid a-spacing-none">...   $2.80  6342522545
# 3  <div class="a-fixed-left-grid a-spacing-none">...   $8.50  6342522898
# 4  <div class="a-fixed-left-grid a-spacing-none">...   $4.50  6342523002
#                                             category tech1  \
# 0  [Clothing, Shoes & Jewelry, Women, Jewelry, Br...
# 1  [Clothing, Shoes & Jewelry, Women, Jewelry, Ne...
# 2  [Clothing, Shoes & Jewelry, Women, Clothing, A...
# 3  [Clothing, Shoes & Jewelry, Costumes & Accesso...
# 4  [Clothing, Shoes & Jewelry, Costumes & Accesso...
#
#                                          description  \
# 0  [This sterling silver plain clip is simple, su...
# 1  [This Stanley London miniature compass in a ha...
# 2  [Ideal for moderate exertion and Colder Climat...
# 3  [Looking for the ultimate disguise? Try a Smif...
# 4  [Vampire Fangs Accessory. Includes dental impr...
#
#                                                  fit  \
# 0
# 1
# 2   class="a-normal a-align-center a-spacing-smal...
# 3   class="a-normal a-align-center a-spacing-smal...
# 4
#
#                                                title  \
# 0                           PANDORA Plain Clip Charm
# 1  Stanley London Sterling Silver Compass Rose Lo...
# 2               Polarmax Women's 4-Way Stretch Tight
# 3           Smiffy's Women's Great War Nurse Costume
# 4           Fangs Dentures Vampire Costume Accessory
#
#                                             also_buy  \
# 0  [B07G4H6C97, B00JQPO1U0, B00B7HMMG0, B01DY3N48...
# 1   [B01BEAXXEO, B01HIQRXE4, B07CGNRR7B, B07CF6SJPK]
# 2                           [B004A9121S, B07C61XLVP]
# 3  [B003XRU6A6, B00362RUES, B00JUKPQ00, B06XCRNGK...
# 4  [B00DVFWFKE, B0042TRXFK, B076113PDM, B000VOEQ8...
#
#                                                image tech2  \
# 0  [https://images-na.ssl-images-amazon.com/image...
# 1  [https://images-na.ssl-images-amazon.com/image...
# 2                                                 []
# 3  [https://images-na.ssl-images-amazon.com/image...
# 4  [https://images-na.ssl-images-amazon.com/image...
#
#                 brand                                            feature  \
# 0             PANDORA  [Crafted from 925 Sterling silver, Plain Clip,...
# 1      Stanley London  [The Compass Rose Design locket features a han...
# 2            Polarmax  [Polyester, Spandex, 92% ACCLIMATE DRY POLYEST...
# 3            Smiffy's  [<a class="a-link-normal a-color-tertiary" hre...
# 4  Fun World Costumes  [Costume Includes Hat Cape (Medallion and cape...
#
#                                                 rank  \
# 0           1,582,564 in Clothing, Shoes & Jewelry (
# 1           1,026,910 in Clothing, Shoes & Jewelry (
# 2                     187,963 in Sports & Outdoors (
# 3             674,848 in Clothing, Shoes & Jewelry (
# 4  [>#277,364 in Toys & Games (See Top 100 in Toy...
#
#                                            also_view  \
# 0  [B00JQPO1U0, B01KMASR3O, B01KMATP44, B013UCJH9...
# 1  [B06XD1V384, B011AI4ZE2, B008N3C3HE, B00M4YC56...
# 2                                                 []
# 3  [B06XCRNGKT, B003XRU6A6, B00TLJYD18, B01KN1KX0...
# 4                                                 []
#
#                                              details  \
# 0                                                 {}
# 1                                                 {}
# 2  {'
#     Product Dimensions:
#     ': '1 x 1 x 1 ...
# 3                                                 {}
# 4                                                 {}
#
#                                             main_cat similar_item  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2                                  Sports & Outdoors
# 3  <img src="https://images-na.ssl-images-amazon....
# 4                                       Toys & Games
#
#                                                 date            price  \
# 0                                            PANDORA
# 1                                     Stanley London           $75.00
# 2                                                     $37.95 - $60.00
# 3  <div class="a-fixed-left-grid a-spacing-none">...
# 4                                                               $5.92
#
#          asin
# 0  B000WNAVT0
# 1  B000WNDM1E
# 2  B000WNEVKU
# 3  B000WNFZ28
# 4  B000WNHH9M
#                                             category tech1  \
# 0  [Clothing, Shoes & Jewelry, Women, Jewelry, Br...
# 1  [Clothing, Shoes & Jewelry, Women, Jewelry, Br...
# 2  [Clothing, Shoes & Jewelry, Women, Jewelry, Br...
# 3  [Clothing, Shoes & Jewelry, Women, Jewelry, Br...
# 4  [Clothing, Shoes & Jewelry, Women, Jewelry, Br...
#
#                                          description  \
# 0                                                 []
# 1  [, An amazing work of art! This cicada bug is ...
# 2  [There's a serene expression on the maiden's f...
# 3  [This trusty steed will be perfect for any hor...
# 4  [Like a moth drawn to a light, we are totally ...
#
#                                                  fit  \
# 0   class="a-normal a-align-center a-spacing-smal...
# 1
# 2
# 3
# 4
#
#                                                title  \
# 0  Alilang Peridot Crystal Rhinestone Ladybug Fly...
# 1  Alilang Womens Silvery Tone Light Pink Rhinest...
# 2  Alilang Silvery Tone Clear Crystal Colored Rhi...
# 3  Alilang Womens Silver Tone Rhinestones Horse S...
# 4  Alilang Gold Tone Iridescent Crystal Colored R...
#
#                                             also_buy  \
# 0  [B01M5DTB5I, B002S1FL4E, B01GHCN5KG, B002ZG36G...
# 1                           [B002S1FL4E, B019KFUB72]
# 2                           [B019750QQG, B003U5X5TA]
# 3                           [B00T6Z19LO, B077R2F2VS]
# 4  [B076X1W2TF, B002S1FL4E, B01J7QQDCQ, B01GHCN5K...
#
#                                                image tech2    brand  \
# 0  [https://images-na.ssl-images-amazon.com/image...        Alilang
# 1  [https://images-na.ssl-images-amazon.com/image...        Alilang
# 2  [https://images-na.ssl-images-amazon.com/image...        Alilang
# 3  [https://images-na.ssl-images-amazon.com/image...        Alilang
# 4  [https://images-na.ssl-images-amazon.com/image...        Alilang
#
#                                              feature  \
# 0  [UNIQUE DESIGN: Brooch with black and green co...
# 1  [UNIQUE DESIGN - Brooch featuring cicada bug d...
# 2  [UNIQUE DESIGN: Brooch with clear crystal colo...
# 3  [UNIQUE DESIGN - Brooch featuring horse design...
# 4  [UNIQUE DESIGN: Moth brooch with crystal/auror...
#
#                                        rank  \
# 0    554,366 in Clothing, Shoes & Jewelry (
# 1  4,180,683 in Clothing, Shoes & Jewelry (
# 2  1,681,924 in Clothing, Shoes & Jewelry (
# 3  1,304,287 in Clothing, Shoes & Jewelry (
# 4    189,337 in Clothing, Shoes & Jewelry (
#
#                                            also_view details  \
# 0  [B01M5DTB5I, B019KFUB72, B07GKJZVG1, B002S1FL4...      {}
# 1                                       [B01C518NXW]      {}
# 2  [B019750QQG, B003U5X5TA, B01N5XOMAC, B01ALPQY5...      {}
# 3                                                 []      {}
# 4  [B07GKJZVG1, B076X1W2TF, B0749CQSWP, B07BFVF4C...      {}
#
#                                             main_cat similar_item  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#                                                 date   price        asin
# 0  <div class="a-fixed-left-grid a-spacing-none">...  $15.99  B001SZVSKW
# 1                                            Alilang  $15.99  B001SZTTX0
# 2                                            Alilang  $14.99  B001SZXQTS
# 3                                            Alilang  $15.99  B001SZVXQQ
# 4                                            Alilang  $15.99  B001SZXRL0
#                                             category tech1  \
# 0  [Clothing, Shoes & Jewelry, Novelty & More, Cl...
# 1  [Clothing, Shoes & Jewelry, Novelty & More, Cl...
# 2  [Clothing, Shoes & Jewelry, Men, Clothing, Act...
# 3  [Clothing, Shoes & Jewelry, Men, Watches, Wris...
# 4  [Clothing, Shoes & Jewelry, Women, Clothing, L...
#
#                                          description  \
# 0  [Designed with input from firefighters for fir...
# 1  [The Men's S/S Station B Class Shirt is design...
# 2  [4120 Badger Adult B-Core Short-Sleeve Perform...
# 3  [G-Shock Men&apos;s Watch G-Shock GA-110B GA-1...
# 4  [Perfect for everyday activities, the Custom F...
#
#                                                  fit  \
# 0
# 1
# 2
# 3
# 4   class="a-normal a-align-center a-spacing-smal...
#
#                                                title  \
# 0  5.11 Tactical #46122 Men's A Class Short Sleev...
# 1  5.11 Men's Station Shirt Class B Short Sleeve ...
# 2  Badger 4120 Adult B-Core Short-Sleeve Performa...
# 3  G-Shock Men's Watch G-Shock GA-110B GA-110B-1A...
# 4  Barely There Women's Customflex-Fit Wire-Free Bra
#
#                                             also_buy  \
# 0  [B005L782K2, B00D9SQUV8, B005L78CVG, B00D076OT...
# 1  [B00D9SQUV8, B005L80XYY, B00D076OTG, B005L6GWO...
# 2               [B07BVPHM4V, B0041Q3SDU, B0041Q3TW0]
# 3  [B07KGKKH4M, B071YJZ1YP, B004YZIBRG, B06ZXZS8G...
# 4  [B00XNC5GDI, B01553MSOC, B00L5YKFA0, B003BEDXG...
#
#                                                image tech2   brand  \
# 0  [https://images-na.ssl-images-amazon.com/image...          5.11
# 1                                                 []          5.11
# 2  [https://images-na.ssl-images-amazon.com/image...        Badger
# 3  [https://images-na.ssl-images-amazon.com/image...         Casio
# 4  [https://images-na.ssl-images-amazon.com/image...
#
#                                              feature  \
# 0  [100-percent-cotton, 5.8-oz 100% cotton twill,...
# 1  [88% Cotton 12% Nylon, Imported, Badge tab inc...
# 2  [4120 Badger Adult B-Core Short-Sleeve Perform...
# 3  [Made in USA, G-Shock Men's Watch G-Shock GA-1...
# 4  [78% Nylon/15% Polyester/7% Spandex, bras clos...
#
#                                        rank  \
# 0            386,984 in Sports & Outdoors (
# 1            261,167 in Sports & Outdoors (
# 2  1,574,771 in Clothing, Shoes & Jewelry (
# 3    516,033 in Clothing, Shoes & Jewelry (
# 4    469,713 in Clothing, Shoes & Jewelry (
#
#                                            also_view  \
# 0  [B005L782K2, B005L78CVG, B005L79R2E, B00KNKYKL...
# 1  [B005L782K2, B005L6GWOQ, B005L78N9W, B005L79R2...
# 2  [B0041Q3SDU, B07BVPHM4V, B00YZSNPP0, B0754131K...
# 3  [B007V2ZZWS, B074MJBVZ1, B072J5578G, B07KGKKH4...
# 4  [B00XNC5GDI, B016S06WH0, B003BEDXG0, B06XZPR9S...
#
#                                              details  \
# 0  {'
#     Product Dimensions:
#     ': '1 x 1 x 1 ...
# 1  {'Shipping Weight:': '2 pounds (', 'Domestic S...
# 2                                                 {}
# 3                                                 {}
# 4                                                 {}
#
#                                             main_cat similar_item  \
# 0                                  Sports & Outdoors
# 1                                  Sports & Outdoors
# 2                                  Sports & Outdoors
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#                                                 date            price  \
# 0                                                     $41.12 - $54.99
# 1                                                     $50.15 - $59.99
# 2  <div class="a-fixed-left-grid a-spacing-none">...   $7.31 - $24.68
# 3                                              Casio            $7.99
# 4  <div class="a-fixed-left-grid a-spacing-none">...           $15.99
#
#          asin
# 0  B003NRR5R8
# 1  B003NRMW5S
# 2  B003NRNSJ2
# 3  B003NS8U58
# 4  B003NSBV86
#                                             category tech1  \
# 0  [Clothing, Shoes & Jewelry, Women, Jewelry, Ea...
# 1  [Clothing, Shoes & Jewelry, Men, Jewelry, Ring...
# 2  [Clothing, Shoes & Jewelry, Novelty & More, Cl...
# 3  [Clothing, Shoes & Jewelry, Men, Surf, Skate &...
# 4  [Clothing, Shoes & Jewelry, Women, Clothing, A...
#
#                                          description  \
# 0                                                 []
# 1  [Solid Sterling Silver "LOVE, LOYALTY, FRIENDS...
# 2                                                 []
# 3  [A classic of years past and for years to come...
# 4  [One of Soffe's classics juniors shorts in a n...
#
#                                                  fit  \
# 0
# 1
# 2
# 3   class="a-normal a-align-center a-spacing-smal...
# 4   class="a-normal a-align-center a-spacing-smal...
#
#                                                title  \
# 0  NOVICA Onyx Cabochon and .925 Sterling Silver ...
# 1  Men's Sterling Silver Claddagh Ring SMS-SG92. ...
# 2                   Volcom Men's Slapdit Slim Hoodie
# 3                        Volcom Mens Full Stone Xfit
# 4          Soffe Women's Juniors' Team Shorty Shorts
#
#                                             also_buy  \
# 0                                       [B00F2V897S]
# 1                                       [B07CBNSZ2V]
# 2                                       [B06XG25FJC]
# 3  [B07DKNXC1M, B076RQPHWG, B07L5FSYF1, B07CRLKNM...
# 4  [B00QYTELMY, B01ES46I54, B005SAC31G, B01DNUH9J...
#
#                                                image tech2  \
# 0  [https://images-na.ssl-images-amazon.com/image...
# 1                                                 []
# 2  [https://images-na.ssl-images-amazon.com/image...
# 3                                                 []
# 4  [https://images-na.ssl-images-amazon.com/image...
#
#                  brand                                            feature  \
# 0               NOVICA  [An original NOVICA fair trade product in asso...
# 1  CLADDAGH RING STORE  [Made in Ireland. Authentic Claddagh Ring, LOV...
# 2                       [55% Cotton/45% Polyester Fleece; 210gm, Machi...
# 3                       [100% Cotton, Six panel XFit Flexfit, Medium h...
# 4                       [100% Polyester, Imported, Machine Wash, 100 p...
#
#                                        rank  \
# 0  2,315,085 in Clothing, Shoes & Jewelry (
# 1    627,458 in Clothing, Shoes & Jewelry (
# 2  2,414,899 in Clothing, Shoes & Jewelry (
# 3    498,070 in Clothing, Shoes & Jewelry (
# 4     69,381 in Clothing, Shoes & Jewelry (
#
#                                            also_view details  \
# 0               [B072YTLGWH, B06XQ5GXWB, B000F6Y5RI]      {}
# 1  [B01DEJE5OA, B01E4GOOUM, B00V61SAJK, B07CBNSZ2...      {}
# 2                                       [B06XG25FJC]      {}
# 3  [B076RQPHWG, B07L5FSYF1, B07DKNXC1M, B00Q4ZOU4...      {}
# 4  [B01DNUH9J8, B00QYTELMY, B01ES46I54, B071FNWL4...      {}
#
#                                             main_cat similar_item  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#                                                 date           price  \
# 0                                             NOVICA          $38.99
# 1                                CLADDAGH RING STORE          $97.00
# 2  <div class="a-fixed-left-grid a-spacing-none">...
# 3  <div class="a-fixed-left-grid a-spacing-none">...          $22.95
# 4  <div class="a-fixed-left-grid a-spacing-none">...  $7.02 - $48.16
#
#          asin
# 0  B004VUB342
# 1  B004VUC0GW
# 2  B004VUGZ8G
# 3  B004VUF4XS
# 4  B004VUK0C8
#                                             category tech1  \
# 0  [Clothing, Shoes & Jewelry, Novelty & More, Je...
# 1  [Clothing, Shoes & Jewelry, Novelty & More, Cl...
# 2  [Clothing, Shoes & Jewelry, Women, Jewelry, Ea...
# 3  [Clothing, Shoes & Jewelry, Women, Accessories...
# 4  [Clothing, Shoes & Jewelry, Costumes & Accesso...
#
#                                          description  \
# 0  [Elegant Thalia Design leather wrap bracelet h...
# 1  [This Muhammad Ali T-shirt is an excellent 100...
# 2  [What's more elegant than an imitation pearl /...
# 3  [Maintain manual dexterity and keep warm at th...
# 4  [Rubies has all the licensed and non-licensed ...
#
#                                                  fit  \
# 0
# 1   class="a-normal a-align-center a-spacing-smal...
# 2
# 3
# 4   class="a-normal a-align-center a-spacing-smal...
#
#                                                title  \
# 0  Elegant &quot;Thalia&quot; Black and White Bea...
# 1       Muhammad Ali T-shirt Adult Run Ali Black Tee
# 2  GirlPROPS(R) Closeout 16&quot; Imitation Pearl...
# 3  Nirvanna Designs MT13F Flower Crochet Hand War...
# 4                       Rubie's Beavis Overhead Mask
#
#                                             also_buy  \
# 0                                       [B071CQJV46]
# 1  [B00943PZJU, B07C5D4HWB, B01LVZY7H8, B07BVC69K...
# 2  [B07L2WP8HT, B00ZF1C1OM, B00GCUWMIA, B005OCT25...
# 3               [B017P5IT0A, B00GZILVOK, B00GZIOO8K]
# 4                                       [B005N50VQA]
#
#                                                image tech2  \
# 0  [https://images-na.ssl-images-amazon.com/image...
# 1                                                 []
# 2  [https://images-na.ssl-images-amazon.com/image...
# 3  [https://images-na.ssl-images-amazon.com/image...
# 4                                                 []
#
#                       brand  \
# 0  Beautiful Silver Jewelry
# 1               A&E Designs
# 2              GirlPROPS(R)
# 3          Nirvanna Designs
# 4
#
#                                              feature  \
# 0  [Stylish and Elegant "Thalia" Black Leather Wr...
# 1  [Click the "A&E Designs" link above to see mor...
# 2  [<span class="a-text-bold">Package Dimensions:...
# 3  [100% wool with fleece lining, Handmade in Nep...
# 4  [100% Plastic, Hand Wash, Three/four vinyl mas...
#
#                                        rank  \
# 0  1,222,045 in Clothing, Shoes & Jewelry (
# 1  1,213,790 in Clothing, Shoes & Jewelry (
# 2    865,643 in Clothing, Shoes & Jewelry (
# 3            224,224 in Sports & Outdoors (
# 4  2,009,547 in Clothing, Shoes & Jewelry (
#
#                                            also_view  \
# 0  [B07DCMMP5J, B01IVAUSMA, B071CQJV46, B073XZXQ3...
# 1  [B00943PZJU, B07KWJ2B6D, B06XMQMFHD, B07C5CM61...
# 2                                       [B07CZ3QX3W]
# 3  [B017P5KHLO, B01M2CV1C8, B00GZIOO8K, B0762VC3G...
# 4  [B005N50VQA, B005KAEXH6, B005F0TU4C, B005N50XW...
#
#                                              details  \
# 0                                                 {}
# 1                                                 {}
# 2                                                 {}
# 3  {'Shipping Weight:': '4 ounces (', 'Domestic S...
# 4                                                 {}
#
#                                             main_cat similar_item  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3                                  Sports & Outdoors
# 4  <img src="https://images-na.ssl-images-amazon....
#
#                                                 date            price  \
# 0                           Beautiful Silver Jewelry           $36.52
# 1  <div class="a-fixed-left-grid a-spacing-none">...  $19.95 - $29.99
# 2                                       GirlPROPS(R)
# 3                                                               $4.02
# 4  <div class="a-fixed-left-grid a-spacing-none">...           $18.38
#
#          asin
# 0  B005IGRMTS
# 1  B005IGXG66
# 2  B005IH9268
# 3  B005IHATIS
# 4  B005IHD0NE
#                                             category tech1  \
# 0  [Clothing, Shoes & Jewelry, Shoe, Jewelry & Wa...
# 1  [Clothing, Shoes & Jewelry, Shoe, Jewelry & Wa...
# 2  [Clothing, Shoes & Jewelry, Shoe, Jewelry & Wa...
# 3  [Clothing, Shoes & Jewelry, Shoe, Jewelry & Wa...
# 4  [Clothing, Shoes & Jewelry, Shoe, Jewelry & Wa...
#
#                                          description  \
# 0  [The Fashion Shoelaces series are made exclusi...
# 1  [These Shoe Laces are 100% Cotton Shoelaces. F...
# 2  [These Heavy Duty ROUND Boot Laces are a great...
# 3  [The Fashion Shoelaces series are made exclusi...
# 4  [These shoelaces come in a variety of colors a...
#
#                                                  fit  \
# 0   class="a-normal a-align-center a-spacing-smal...
# 1   class="a-normal a-align-center a-spacing-smal...
# 2   class="a-normal a-align-center a-spacing-smal...
# 3   class="a-normal a-align-center a-spacing-smal...
# 4   class="a-normal a-align-center a-spacing-smal...
#
#                                                title  \
# 0  Fashion Casual / Athletic Round Shoelaces 2 Pa...
# 1              Cotton Shoelaces 3/8 inch 2 Pair Pack
# 2            Heavy Duty Round Boot Laces 2 Pair Pack
# 3        Fashion Flat Athletic Shoelaces 2 Pair Pack
# 4                Waxed Dress Round Laces 2 Pair Pack
#
#                                             also_buy  \
# 0  [B07CR8GKPY, B007ATEC5S, B007BPGGF0, B07KPMR9T...
# 1               [B007BFM9PG, B07LGDD1KQ, B01N22BOHP]
# 2  [B002WWT9YM, B00XQ6U42E, B00ROCH74E, B072JCLR4...
# 3  [B007ATJ9HY, B07JVKQ7F3, B007ATF48C, B01EJSEXB...
# 4  [B06XBS21L2, B0748TR6Q1, B00ZY1J1JG, B01EJQ6Z7...
#
#                                                image tech2             brand  \
# 0  [https://images-na.ssl-images-amazon.com/image...        ShoeLacesExpress
# 1                                                 []        ShoeLacesExpress
# 2  [https://images-na.ssl-images-amazon.com/image...        ShoeLacesExpress
# 3  [https://images-na.ssl-images-amazon.com/image...        ShoeLacesExpress
# 4  [https://images-na.ssl-images-amazon.com/image...        ShoeLacesExpress
#
#                                              feature  \
# 0  [REGARDLESS OF QUANTITY $5.95 Flat Rate Shippi...
# 1  [REGARDLESS OF QUANTITY $5.95 Flat Rate Shippi...
# 2  [REGARDLESS OF QUANTITY $5.95 Flat Rate Shippi...
# 3  [REGARDLESS OF QUANTITY $5.95 Flat Rate Shippi...
# 4  [polyester, Shoe Lace Width (Diameter) - appro...
#
#                                        rank  \
# 0     68,871 in Clothing, Shoes & Jewelry (
# 1  1,409,139 in Clothing, Shoes & Jewelry (
# 2    345,146 in Clothing, Shoes & Jewelry (
# 3    414,968 in Clothing, Shoes & Jewelry (
# 4    591,366 in Clothing, Shoes & Jewelry (
#
#                                            also_view details  \
# 0  [B00ZG2SVC6, B07KPMR9T4, B07JYHP34X, B07CR8GKP...      {}
# 1  [B07L4ZLGC1, B01MEH3YAC, B06WV98TB7, B01N30031...      {}
# 2  [B075DFG8G1, B011AI2LMK, B07CFL1LBH, B01ABU0QW...      {}
# 3  [B07L4ZLGC1, B01695QDSM, B072LM9JKG, B007ATJ9H...      {}
# 4  [B01EJF0FFG, B07JYG4WG3, B07CLLL1V8, B06XBS21L...      {}
#
#                                             main_cat similar_item  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#                                                 date           price  \
# 0  <div class="a-fixed-left-grid a-spacing-none">...   $8.88 - $9.38
# 1  <div class="a-fixed-left-grid a-spacing-none">...   $6.99 - $7.49
# 2  <div class="a-fixed-left-grid a-spacing-none">...  $9.99 - $14.40
# 3  <div class="a-fixed-left-grid a-spacing-none">...   $8.88 - $9.38
# 4  <div class="a-fixed-left-grid a-spacing-none">...  $5.95 - $13.44
#
#          asin
# 0  B00773AEY0
# 1  B00773AJW2
# 2  B00773B6B0
# 3  B00773BZUC
# 4  B00773BSEU
#                                             category tech1  \
# 0  [Clothing, Shoes & Jewelry, Women, Shoes, Sand...
# 1  [Clothing, Shoes & Jewelry, Girls, Accessories...
# 2  [Clothing, Shoes & Jewelry, Women, Clothing, S...
# 3  [Clothing, Shoes & Jewelry, Women, Watches, Wr...
# 4  [Clothing, Shoes & Jewelry, Boys, Clothing, Pa...
#
#                                          description  \
# 0  [Complete your brunch ensemble with the effort...
# 1  [Newbee Fashion's Kyra Kids Collection include...
# 2  [Stretch Knit Low Rise Dance & Yoga Tights. Se...
# 3  [Stainless steel caseback. Gold-tone mixed met...
# 4  [Material: 65% Polyester. 35% Viscose Flat Fro...
#
#                                                  fit  \
# 0
# 1
# 2   class="a-normal a-align-center a-spacing-smal...
# 3
# 4   class="a-normal a-align-center a-spacing-smal...
#
#                                                title  \
# 0  SAS Womens Strippy Open Toe Casual Ankle Strap...
# 1  Kyra Kids Girls Plastic Polka Dot Bow Sunglass...
# 2  Sexy, Chic &amp; Warm Stretch Knit Gym Tights ...
# 3  Anne Klein Women's AK/1028BKGB Swarovski Cryst...
# 4  Armando Martillo Boys Flat Front Adjustable Wa...
#
#                                             also_buy  \
# 0  [B005DGGA96, B00MOP7FAC, B078ZZBTMH, B077MKW8V...
# 1  [B00O2Q4NUQ, B07FB5FPVN, B07CDVZY17, B06Y43B4P...
# 2  [B07CPFVY7F, B06XJFB5X9, B07CM5MC8M, B007E67Z0...
# 3  [B078YC6722, B07BQYPR84, B076W3VKD5, B07HSC459...
# 4  [B00WJOAB86, B07BZWZLWG, B077WW3H23, B0194PYFZ...
#
#                                                image tech2              brand  \
# 0  [https://images-na.ssl-images-amazon.com/image...                      SAS
# 1  [https://images-na.ssl-images-amazon.com/image...                Kyra Kids
# 2  [https://images-na.ssl-images-amazon.com/image...        KD dance New York
# 3  [https://images-na.ssl-images-amazon.com/image...
# 4  [https://images-na.ssl-images-amazon.com/image...         Armando Martillo
#
#                                              feature  \
# 0  [Leather, Made in USA, Rubber sole, Ankle stra...
# 1  [plastic frame, plastic lens, non-polarized, L...
# 2  [Stretch Knit Ribbed Low Rise Tights by KD dan...
# 3  [Imported, Gold-tone watch featuring sleek bla...
# 4  [Material: 65% Polyester., 35% Viscose., Flat ...
#
#                                        rank  \
# 0  4,759,224 in Clothing, Shoes & Jewelry (
# 1    355,579 in Clothing, Shoes & Jewelry (
# 2    442,090 in Clothing, Shoes & Jewelry (
# 3  1,008,915 in Clothing, Shoes & Jewelry (
# 4    256,093 in Clothing, Shoes & Jewelry (
#
#                                            also_view details  \
# 0  [B005DGGA96, B01N76VQ11, B00MV9CYPM, B00MOP7FA...      {}
# 1  [B07CDVZY17, B07GQJTD47, B07BCG658Q, B00O2Q4NU...      {}
# 2  [B07CM5MC8M, B07CPFVY7F, B00K841J0I, B007E67Z0...      {}
# 3                           [B076W3VKD5, B07BQYPR84]      {}
# 4  [B06XXYQV6W, B06XPRYWC2, B01MZIXYX0, B077WW3H2...      {}
#
#                                             main_cat similar_item  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#                                                 date             price  \
# 0  <div class="a-fixed-left-grid a-spacing-none">...  $47.05 - $119.90
# 1  <div class="a-fixed-left-grid a-spacing-none">...             $7.99
# 2  <div class="a-fixed-left-grid a-spacing-none">...   $37.95 - $42.96
# 3                                         Anne Klein
# 4  <div class="a-fixed-left-grid a-spacing-none">...   $24.00 - $29.50
#
#          asin
# 0  B008XOFI66
# 1  B008XPGJZE
# 2  B008XS29YQ
# 3  B008XT3P0M
# 4  B008XTXI2M
#                                             category tech1  \
# 0  [Clothing, Shoes & Jewelry, Novelty & More, Cl...
# 1  [Clothing, Shoes & Jewelry, Women, Jewelry, Ri...
# 2  [Clothing, Shoes & Jewelry, Women, Jewelry, Ri...
# 3  [Clothing, Shoes & Jewelry, Novelty & More, Cl...
# 4  [Clothing, Shoes & Jewelry, Women, Jewelry, Ri...
#
#                                          description  \
# 0                                                 []
# 1  [This piece of jewelry would be a wonderful ad...
# 2  [This piece of jewelry would be a wonderful ad...
# 3  [Lace fishnet halter garter dress with opaque ...
# 4  [This piece of jewelry would be a wonderful ad...
#
#                                                  fit  \
# 0
# 1
# 2
# 3   class="a-normal a-align-center a-spacing-smal...
# 4
#
#                                                title  \
# 0     Naked &amp; Famous Denim Men's Slim Fit Hoodie
# 1  925 Sterling Silver 18 mm Detailed Celtic Tree...
# 2  925 Sterling Silver 20 mm Vintage Style Detail...
# 3  Dreamgirl Women's Plus-Size Trinidad Halter Ga...
# 4  925 Sterling Silver Double Infinity Together F...
#
#                                             also_buy  \
# 0                                       [B00APU47V8]
# 1                           [B009L0YMKO, B07BYDL1FG]
# 2  [B002E3KWTK, B006FX768U, B00YX7G6TK, B01II2XM6...
# 3  [B06XTF12W5, B00APUNW0K, B000ZHGCA0, B00P2GX04...
# 4  [B01LWQM6MU, B077JHKTK4, B077H8P23V, B074DV89G...
#
#                                                image tech2  \
# 0  [https://images-na.ssl-images-amazon.com/image...
# 1  [https://images-na.ssl-images-amazon.com/image...
# 2  [https://images-na.ssl-images-amazon.com/image...
# 3  [https://images-na.ssl-images-amazon.com/image...
# 4  [https://images-na.ssl-images-amazon.com/image...
#
#                   brand                                            feature  \
# 0  Naked & Famous Denim  [100% Cotton, Imported, Cold Wash / Hang Dry, ...
# 1                        [Width: 18 mm, Lightweight and beautiful, Pack...
# 2               Chuvora  [Width: 20 mm, Lightweight and beautiful, Pack...
# 3                        [90% Nylon, 10% Spandex, Hand Wash, Garter dre...
# 4                        [Width: 9 mm, Lightweight and beautiful, Packa...
#
#                                        rank  \
# 0  4,940,431 in Clothing, Shoes & Jewelry (
# 1    938,963 in Clothing, Shoes & Jewelry (
# 2    130,199 in Clothing, Shoes & Jewelry (
# 3    836,983 in Clothing, Shoes & Jewelry (
# 4    353,274 in Clothing, Shoes & Jewelry (
#
#                                            also_view details  \
# 0                                       [B00APU47V8]      {}
# 1  [B00IS8AL28, B071P275GL, B071YTT11N, B00FX92FK...      {}
# 2  [B075RYDGH1, B0751SGSHK, B07C91X7J6, B019P5YOI...      {}
# 3  [B00AKQ9NY8, B000ZHGCA0, B07D4CG7GK, B07873R8P...      {}
# 4  [B01LWQM6MU, B07CNBGHNP, B01LYQTB11, B072NFTFJ...      {}
#
#                                             main_cat similar_item  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#                                                 date            price  \
# 0  <div class="a-fixed-left-grid a-spacing-none">...
# 1                                            Chuvora
# 2                                            Chuvora           $19.99
# 3  <div class="a-fixed-left-grid a-spacing-none">...           $26.99
# 4                                            Chuvora  $14.28 - $15.23
#
#          asin
# 0  B00APU4TDY
# 1  B00APUP5I2
# 2  B00APUP9LA
# 3  B00APUNZF2
# 4  B00APUP686
#                                             category tech1  \
# 0  [Clothing, Shoes & Jewelry, Costumes & Accesso...
# 1  [Clothing, Shoes & Jewelry, Costumes & Accesso...
# 2  [Clothing, Shoes & Jewelry, Costumes & Accesso...
# 3  [Clothing, Shoes & Jewelry, Costumes & Accesso...
# 4  [Clothing, Shoes & Jewelry, Costumes & Accesso...
#
#                                          description  \
# 0  [Rubie's costume company has the licensed and ...
# 1  [Rubie's costume company has been bringing cos...
# 2  [Rubie's costume company has been bringing cos...
# 3  [Rubie's costume Company has been bringing cos...
# 4  [Rubie's costume company has been bringing cos...
#
#                                                  fit  \
# 0
# 1   class="a-normal a-align-center a-spacing-smal...
# 2
# 3
# 4   class="a-normal a-align-center a-spacing-smal...
#
#                                                title  \
# 0  Rubie's Costume Deluxe Medieval Warrior Cloak ...
# 1  Rubie's Men's Despicable Me 2 Minion Dave Costume
# 2  Rubie's Costume The Smurfs 2 Adult Vinyl Brain...
# 3  Star Wars Secret Wishes Female Darth Vader Cos...
# 4                Rubie's Costume Smurf Adult Mittens
#
#                                             also_buy  \
# 0  [B07D33ZLLW, B007E9RDEQ, B01GV883MQ, B00O173B7...
# 1  [B00BZ5R8GS, B00BZ5Y99C, B00BZ5Y94C, B00BZ5QSC...
# 2                                       [B00BZ5PPEA]
# 3  [B00XVX3RM6, B00BZ5X9E8, B000XZ6XZS, B01C5CS7F...
# 4  [B07H554N6S, B076JY2N92, B00842PE52, B00BG34DX...
#
#                                                image tech2 brand  \
# 0                                                 []
# 1  [https://images-na.ssl-images-amazon.com/image...
# 2  [https://images-na.ssl-images-amazon.com/image...
# 3  [https://images-na.ssl-images-amazon.com/image...
# 4                                                 []
#
#                                              feature  \
# 0  [100% Polyester, Imported, Hand Wash, Long men...
# 1  [100% Polyester, Imported, Hand Wash, 4" high,...
# 2  [100% Vinyl, Imported, Hand Wash, 3.94" high, ...
# 3  [100% Polyester, Imported, Hand Wash, 2.5" hig...
# 4  [100% Polyester, Imported, Hand Wash, Adult si...
#
#                                        rank  \
# 0  1,424,966 in Clothing, Shoes & Jewelry (
# 1    640,391 in Clothing, Shoes & Jewelry (
# 2  4,524,015 in Clothing, Shoes & Jewelry (
# 3                                        []
# 4  1,797,052 in Clothing, Shoes & Jewelry (
#
#                                            also_view details  \
# 0  [B014B211YG, B0713MK8RJ, B0718SW3CR, B00OBVU7U...      {}
# 1  [B00BZ5R8GS, B00TO6E4BM, B06VXM7N6M, B00TO6E4C...      {}
# 2                                                 []      {}
# 3  [B00IPDUII8, B00BZ5R1U6, B00BZ5SFWE, B00BZ5X9E...      {}
# 4  [B01NCW7DVH, B00BG34DXK, B06X412SNW, B06WVGZD6...      {}
#
#                                             main_cat similar_item  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3                                       Toys & Games
# 4  <img src="https://images-na.ssl-images-amazon....
#
#                                                 date   price        asin
# 0  <div class="a-fixed-left-grid a-spacing-none">...  $28.61  B00BZ5SR54
# 1  <div class="a-fixed-left-grid a-spacing-none">...  $27.99  B00BZ5R84K
# 2  <div class="a-fixed-left-grid a-spacing-none">...          B00BZ5TCOO
# 3  <div class="a-fixed-left-grid a-spacing-none">...  $36.91  B00BZ5R1U6
# 4  <div class="a-fixed-left-grid a-spacing-none">...  $13.99  B00BZ5TCI0
#                                             category tech1  \
# 0  [Clothing, Shoes & Jewelry, Women, Jewelry, Ne...
# 1  [Clothing, Shoes & Jewelry, Women, Jewelry, Ne...
# 2  [Clothing, Shoes & Jewelry, Women, Jewelry, Ne...
# 3  [Clothing, Shoes & Jewelry, Women, Jewelry, Ne...
# 4  [Clothing, Shoes & Jewelry, Women, Jewelry, Ne...
#
#                                          description fit  \
# 0  [This Sideways Cross necklace is made of solid...
# 1  [This Sideways Cross necklace is made of solid...
# 2  [Choose any name to personalize this 18k Rose ...
# 3  [This Sideways Cross necklace is made of solid...
# 4  [This Sideways Cross necklace is made of 18k G...
#
#                                                title  \
# 0  Cross Pendant Silver Cross Necklace-sideways C...
# 1  Cross Pendant Silver Cross Necklace-sideways C...
# 2  18k Rose Gold Plate Name Necklace - Custom Mad...
# 3  Cross Pendant Silver Cross Necklace-sideways C...
# 4  Cross Pendant Sideways Cross Necklace-gold Pla...
#
#                                             also_buy image tech2  \
# 0                                       [B07CL3YX8B]    []
# 1                           [B00X12CQ74, B07BMZHF75]    []
# 2  [B07C8D7HR5, B07C5F6NLJ, B0070UL4IA, B00X5K8DM...    []
# 3  [B07C9RPRY2, B07CL3YX8B, B00DFVNU6C, B00ST9W31...    []
# 4  [B01KO7FW88, B07BMZHF75, B07D3L34LR, B00DFVNU6...    []
#
#                     brand                                            feature  \
# 0  Personalized Necklaces  [Sideways Cross Necklace, The default style wi...
# 1  Personalized Necklaces  [Sideways Cross Necklace, The default style wi...
# 2  Personalized Necklaces  [Personalize this necklace with any name, Next...
# 3  Personalized Necklaces  [The default style will have the pendant cente...
# 4  Personalized Necklaces  [Sideways Cross Necklace, Material: 925 Sterli...
#
#                                        rank  \
# 0  1,735,613 in Clothing, Shoes & Jewelry (
# 1  1,301,027 in Clothing, Shoes & Jewelry (
# 2    856,334 in Clothing, Shoes & Jewelry (
# 3    556,936 in Clothing, Shoes & Jewelry (
# 4    834,623 in Clothing, Shoes & Jewelry (
#
#                                            also_view details  \
# 0  [B07D3L34LR, B01NBEOSJ5, B01KO7FW88, B013W3ELU...      {}
# 1  [B01KO7FW88, B07D3L34LR, B07CL3YX8B, B00AG04UL...      {}
# 2  [B07GGZFTX1, B01GROS8LK, B07C5F6NLJ, B01MPW3Z0...      {}
# 3  [B01NBEOSJ5, B07D3L34LR, B013W3ELU6, B07CL3YX8...      {}
# 4  [B01A7BM7P2, B07D3L34LR, B00AG8BJ92, B00TSOENA...      {}
#
#                                             main_cat  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#                                         similar_item                    date  \
# 0                                                     Personalized Necklaces
# 1                                                     Personalized Necklaces
# 2                                                     Personalized Necklaces
# 3                                                     Personalized Necklaces
# 4   class="a-bordered a-horizontal-stripes  a-spa...  Personalized Necklaces
#
#     price        asin
# 0  $19.99  B00DFVNU8K
# 1  $19.99  B00DFVNU9O
# 2  $28.99  B00DFWE2OA
# 3  $19.99  B00DFVNUD0
# 4   $6.58  B00DFVTEY4
#                                             category tech1  \
# 0  [Clothing, Shoes & Jewelry, Women, Handbags & ...
# 1  [Clothing, Shoes & Jewelry, Women, Jewelry, Ne...
# 2  [Clothing, Shoes & Jewelry, Women, Watches, Wr...
# 3  [Clothing, Shoes & Jewelry, Women, Jewelry, Ea...
# 4  [Clothing, Shoes & Jewelry, Women, Clothing, S...
#
#                                          description fit  \
# 0  [Out of Print pouch bag with a Edgar Allen Poe...
# 1  [This is our Flagship Firefighter Charm inlaid...
# 2  [Pulsar, Night Out, Women's Watch, Stainless S...
# 3                                                 []
# 4  [Suprisingly functional, supremely attractive ...
#
#                                                title  \
# 0                     Out of Print Poe-ka Dots Pouch
# 1  Firefighter Fireman Shield Clear Crystal Red E...
# 2  Pulsar Women's PP6106 Analog Display Japanese ...
# 3  WithLoveSilver 925 Sterling Silver Teeny Bali ...
# 4       La Sportiva Athena Insulated Skirt - Women's
#
#                                             also_buy  \
# 0  [B00KGKQ40E, B018BGCCVY, 1454921358, B00TJ3AFK...
# 1                                       [B00BXQ4WLS]
# 2  [B00RZC6YY2, B077N9CLDG, B004JBB3ZM, B00EUJEER...
# 3                                       [B000CQZZ5M]
# 4                           [B00V9XKNRC, B00V9XKOFI]
#
#                                                image tech2  \
# 0                                                 []
# 1                                                 []
# 2  [https://images-na.ssl-images-amazon.com/image...
# 3                                                 []
# 4                                                 []
#
#                     brand                                            feature  \
# 0            Out of Print  [Printed canvas, Zipper enclosure, 6" h x 9" w...
# 1  Sports Accessory Store  [Approximately 18 Inches in Diameter Silver Pl...
# 2                  Pulsar  [Imported, Multi-hands, Light gold, Dress spor...
# 3          WithLoveSilver  [More Bali Jewelry available in our store. Ple...
# 4                          [Yes, youre a goddess, dont ever let them forg...
#
# ...
#
#                                            also_view  \
# 0                                                 []
# 1  [B07D5M51D7, B079YV47ZT, B07M686G41, B07M6MHJX...
# 2  [B07LFJFDSY, B07DVR4NJF, B06XHBTTB7, B00LGUU0X...
# 3  [B00IE69JR2, B01NBM84ZC, B00PCLPQI8, B01KXTZVJ...
# 4  [B07JQ2GTF9, B074G3M738, B07DTPF9GP, B07J9K8J6...
#
#                                              details           main_cat  \
# 0  {'Shipping Weight:': '5 pounds', 'ASIN: ': 'B0...  Sports & Outdoors
# 1                           {'ASIN: ': 'B07MBBSBKQ'}  Sports & Outdoors
# 2  {'
#     Product Dimensions:
#     ': '11 x 10 x ...  Sports & Outdoors
# 3                           {'ASIN: ': 'B0171GGBM6'}  Sports & Outdoors
# 4                           {'ASIN: ': 'B00NVJLN4E'}  Sports & Outdoors
#
#   similar_item date            price        asin
# 0                                     B00NVIEX6K
# 1                                     B00NVIAWQK
# 2                    $52.80 - $69.95  B00NVIS2KI
# 3                             $68.99  B00NVJHJBK
# 4                     $6.69 - $18.99  B00NVJLNC6
#                                             category tech1  \
# 0  [Sports & Outdoors, Fan Shop, Pet Gear, Pet Le...
# 1  [Sports & Outdoors, Fan Shop, Clothing, T-Shirts]
# 2   [Sports & Outdoors, Fan Shop, Clothing, Jerseys]
# 3   [Sports & Outdoors, Fan Shop, Clothing, Jerseys]
# 4   [Sports & Outdoors, Fan Shop, Clothing, Jerseys]
#
#                                          description  \
# 0  [This NFL collar bandana is designed to get yo...
# 1  [Show your love for your team in the official ...
# 2  [Show your love for your team in the official ...
# 3  [Show your love for your team in the official ...
# 4  [Be the first to join in the celebration of th...
#
#                                                  fit  \
# 0
# 1   class="a-normal a-align-center a-spacing-smal...
# 2   class="a-normal a-align-center a-spacing-smal...
# 3
# 4   class="a-normal a-align-center a-spacing-smal...
#
#                                                title  \
# 0  NFL PET ACCESSORIES - Largest Selection! 32 FO...
# 1  adidas MLS New York City FC Men's Replica Shor...
# 2  adidas MLS Womens Replica Short Sleeve Team Je...
# 3  MLS New York City FC Women's Replica Short Sle...
# 4  Adidas NYC Football Club Youth Replica Short S...
#
#                                             also_buy  \
# 0   [B00WO40KK0, B00NIMBYQQ, B00WMLL6JE, B00YJKXGBM]
# 1  [B01B6N8XJ4, B00Y1MK1X4, B076LF1ZZR, B076LSPG8...
# 2  [B01B6N8XJ4, B01MYHEL0R, B076LSPG8S, B076K7QXW...
# 3                                       [B00QNYJSS2]
# 4  [B077V71LQ4, B076K7QXWC, B00USC39C6, B01F1U6W2...
#
#                                                image tech2       brand  \
# 0  [https://images-na.ssl-images-amazon.com/image...        Pets First
# 1  [https://images-na.ssl-images-amazon.com/image...            adidas
# 2  [https://images-na.ssl-images-amazon.com/image...            adidas
# 3  [https://images-na.ssl-images-amazon.com/image...            adidas
# 4  [https://images-na.ssl-images-amazon.com/image...            adidas
#
#                                              feature  \
# 0  [Embroidered team logo sewn into team color st...
# 1  [Direct take down of the on-field jersey, 100%...
# 2  [Direct take down of the on-field jersey, 100%...
# 3  [Direct take down of the on-field jersey, 100%...
# 4  [Direct take down of the on-field jersey, 100%...
#
#                                rank  \
# 0         140,655 in Pet Supplies (
# 1    360,565 in Sports & Outdoors (
# 2     83,528 in Sports & Outdoors (
# 3  1,163,420 in Sports & Outdoors (
# 4    438,613 in Sports & Outdoors (
#
#                                            also_view  \
# 0  [B01IRECZOE, B003VGYTR0, B01LYZ172Y, B00WO4003...
# 1  [B00Y1MK1X4, B01B6N8XJ4, B07CJ15XXH, B076LSPG8...
# 2  [B01MYHEL0R, B01MTGASGF, B01B6N8XJ4, B076LSPG8...
# 3                                                 []
# 4  [B077V71LQ4, B076K7QXWC, B075TQ3SL2, B07KS6QG4...
#
#                                              details           main_cat  \
# 0  {'
#     Product Dimensions:
#     ': '22 x 0.1 x...       Pet Supplies
# 1  {'ASIN: ': 'B077V71LQ4', 'Item model number:':...  Sports & Outdoors
# 2  {'
#     Product Dimensions:
#     ': '6 x 6 x 6 ...  Sports & Outdoors
# 3  {'
#     Product Dimensions:
#     ': '13 x 6 x 0...  Sports & Outdoors
# 4  {'
#     Product Dimensions:
#     ': '13 x 6 x 0...  Sports & Outdoors
#
#   similar_item date            price        asin
# 0                                     B00QNVEQPA
# 1                    $39.99 - $69.95  B00QNYJDRS
# 2                    $11.40 - $69.99  B00QNYJUQM
# 3                             $45.00  B00QNYJQYS
# 4                             $44.00  B00QNYJYYA
#                                             category tech1  \
# 0  [Sports & Outdoors, Outdoor Recreation, Campin...
# 1  [Sports & Outdoors, Outdoor Recreation, Campin...
# 2  [Sports & Outdoors, Outdoor Recreation, Campin...
# 3  [Sports & Outdoors, Outdoor Recreation, Outdoo...
# 4  [Sports & Outdoors, Outdoor Recreation, Campin...
#
#                                          description  \
# 0  [At Goodhew we are committed to crafting lifes...
# 1  [At Goodhew we are committed to crafting lifes...
# 2  [At Goodhew we are committed to crafting lifes...
# 3  [At Goodhew we are committed to crafting lifes...
# 4  [Sockwell is reinventing the therapeutic sock,...
#
#                                                  fit  \
# 0
# 1
# 2   class="a-normal a-align-center a-spacing-smal...
# 3
# 4   class="a-normal a-align-center a-spacing-smal...
#
#                                           title  \
# 0                   Sockwell Men's Canyon Socks
# 1            Sockwell Women's Hot Springs Socks
# 2                 Sockwell Women's Kimono Socks
# 3             Sockwell Women's Fan Flower Socks
# 4  Sockwell Women's Relaxed Fit Kick Back Socks
#
#                                             also_buy  \
# 0  [B003E46OUE, B00BWFS0LI, B00BWFS0LS, B01E5G1SL...
# 1  [B01E5G1K1C, B01E5G1I3W, B005P9LV4A, B00KMO1VC...
# 2  [B06Y4TK92J, B06Y4QCQ2C, B06Y4T4TDP, B01E5G1MY...
# 3  [B00KMO1MT2, B00H1QYOEO, B008339D5E, B0091OKWV...
# 4  [B00H2BY290, B00TXNKQK4, B00KMTJD52, B0091OKWV...
#
#                                                image tech2     brand  \
# 0  [https://images-na.ssl-images-amazon.com/image...        Sockwell
# 1  [https://images-na.ssl-images-amazon.com/image...        Sockwell
# 2  [https://images-na.ssl-images-amazon.com/image...        Sockwell
# 3                                                 []        Sockwell
# 4  [https://images-na.ssl-images-amazon.com/image...        Sockwell
#
#                                              feature  \
# 0  [33% merino Wool/33% Bamboo Rayon/29% Nylon/5%...
# 1  [50% Merino Wool, 30% Nylon, 17% Alpaca, 3% Sp...
# 2  [33% Merino Wool/33% Bamboo Rayon/29% Stretch ...
# 3  [33% Merino Wool, 33% Bamboo Rayon, 29% Stretc...
# 4  [35% merino Wool/35% Bamboo Rayon/26% Nylon/4%...
#
#                              rank  \
# 0  714,819 in Sports & Outdoors (
# 1  330,767 in Sports & Outdoors (
# 2  645,611 in Sports & Outdoors (
# 3  743,786 in Sports & Outdoors (
# 4  448,501 in Sports & Outdoors (
#
#                                            also_view  \
# 0  [B00TXN8Y8U, B00BWFS0LS, B00KMO1P62, B00BWFS0L...
# 1  [B005P9LV4A, B00TXN95JW, B01E5G1K1C, B01E5G1ND...
# 2  [B01M7ZSWR4, B01M5LGF3J, B01E5G1NDC, B00TXN95J...
# 3                                                 []
# 4  [B008339PUW, B0072CYIFC, B008338RXI, B005P9LV4...
#
#                                              details           main_cat  \
# 0  {'Shipping Weight:': '1 pounds (', 'Domestic S...  Sports & Outdoors
# 1  {'Shipping Weight:': '1 pounds (', 'Domestic S...  Sports & Outdoors
# 2  {'Shipping Weight:': '2.4 ounces (', 'Domestic...  Sports & Outdoors
# 3  {'
#     Product Dimensions:
#     ': '8 x 4 x 1 ...  Sports & Outdoors
# 4  {'Shipping Weight:': '1.6 ounces (', 'ASIN: ':...  Sports & Outdoors
#
#   similar_item date           price        asin
# 0                    $5.40 - $14.67  B00TXNCK7Q
# 1                    $8.06 - $20.99  B00TXNDGQA
# 2                            $17.99  B00TXNCYEA
# 3                                    B00TXNDN8Q
# 4                            $17.99  B00TXNGXLU
#                                             category tech1  \
# 0  [Sports & Outdoors, Outdoor Recreation, Water ...
# 1  [Sports & Outdoors, Outdoor Recreation, Water ...
# 2  [Sports & Outdoors, Fan Shop, Home & Kitchen, ...
# 3  [Sports & Outdoors, Fan Shop, Home & Kitchen, ...
# 4  [Sports & Outdoors, Fan Shop, Home & Kitchen, ...
#
#                                          description fit  \
# 0  [There are only two kinds of snorkeling masks ...
# 1                                                 []
# 2  [NBA BROOKLYN NETS SHOWER CURTAIN NETS, Shower...
# 3  [Made of 100% polyester jersey. Includes 3-inc...
# 4  [NBA BROOKLYN NETS SHOWER CURTAIN NETS, Shower...
#
#                                                title  \
# 0  EASYBREATH Innovation Snorkelling Mask (Blue, ...
# 1  Poppin Kicks Full Face Snorkel Mask for Adult ...
# 2  Sports Coverage NBA Unisex-Adult,Unisex-Childr...
# 3                   Sports Coverage NBA Mens Valance
# 4  Sports Coverage NBA Unisex-Adult,Unisex-Childr...
#
#                                             also_buy  \
# 0  [B01CX96X8S, B07BMM2JB7, B001PR1326, B000GFZZO...
# 1  [B078B6YZPX, B073QHVZ7W, B00YD9KNI8, B07CBN9MQ...
# 2  [B00R55BCX2, B002QR76GG, B077QRNYGY, B01LO84CH...
# 3  [B01EM4NN6C, B07285SDQM, B0053FOY9A, B07643PB1...
# 4  [B00R55BCX2, B002QR76GG, B077QRNYGY, B01LO84CH...
#
#                                                image tech2            brand  \
# 0  [https://images-na.ssl-images-amazon.com/image...                BROGEND
# 1  [https://images-na.ssl-images-amazon.com/image...           Poppin Kicks
# 2  [https://images-na.ssl-images-amazon.com/image...        Sports Coverage
# 3  [https://images-na.ssl-images-amazon.com/image...        Sports Coverage
# 4  [https://images-na.ssl-images-amazon.com/image...        Sports Coverage
#
#                                              feature  \
# 0  [Innovative Product:Full mask for natural brea...
# 1  [PERFECT VISIBILITY - the mask offers a curved...
# 2  [100% Polyester, Imported, Shower Curtain is 1...
# 3  [100% Polyester Jersey, Imported, Valance is 1...
# 4  [100% Polyester, Imported, Shower Curtain is 1...
#
#                              rank  \
# 0  653,533 in Sports & Outdoors (
# 1   24,584 in Sports & Outdoors (
# 2  256,976 in Sports & Outdoors (
# 3  265,532 in Sports & Outdoors (
# 4  256,976 in Sports & Outdoors (
#
#                                            also_view  \
# 0                           [B07C5FJ8VC, B078YQMTLY]
# 1  [B07KCHLDSC, B078B6YZPX, B0745TVFYZ, B07CRKBZ2...
# 2  [B00R55BCX2, B077QRNYGY, B002QR76GG, B07GQJ6GJ...
# 3  [B01EM4NN6C, B01ITMCWUG, B002QR76ES, B075BDVQS...
# 4  [B00R55BCX2, B077QRNYGY, B002QR76GG, B07GQJ6GJ...
#
#                                              details           main_cat  \
# 0  {'Shipping Weight:': '1.6 pounds (', 'ASIN: ':...  Sports & Outdoors
# 1                           {'ASIN: ': 'B07D3SHVQ3'}  Sports & Outdoors
# 2  {'Domestic Shipping: ': 'Item can be shipped w...  Sports & Outdoors
# 3  {'
#     Product Dimensions:
#     ': '11 x 8 x 5...        Amazon Home
# 4  {'Domestic Shipping: ': 'Item can be shipped w...  Sports & Outdoors
#
#   similar_item date            price        asin
# 0                              $7.42  B00X2JSG52
# 1                    $34.89 - $45.89  B00X2JSG5W
# 2                    $12.11 - $51.13  B00X2MMPWY
# 3                    $17.99 - $23.99  B00X2MM33U
# 4                    $12.11 - $51.13  B00X2MLVZG
#                                             category tech1  \
# 0  [Sports & Outdoors, Sports & Fitness, Hunting ...
# 1  [Sports & Outdoors, Sports & Fitness, Hunting ...
# 2  [Sports & Outdoors, Outdoor Recreation, Campin...
# 3  [Sports & Outdoors, Outdoor Recreation, Campin...
# 4                                                 []
#
#                                          description fit  \
# 0  [An Exclusive product of Green Blob Outdoors -...
# 1  [Allows you to attach any spincast style reel ...
# 2                                                 []
# 3  [Outdoor Hiking Fishing Lawn Portable Pocket F...
# 4                                                 []
#
#                                                title  \
# 0  Green Blob Outdoors Tactical Micro Iron Sight ...
# 1  GPP&reg; Bowfishing Fly Fishing Heavy Duty GPP...
# 2                                   Flexzion Camping
# 3  Flexzion Camping Folding Stool - Portable 3 Le...
# 4  Z ZTDM Rock Hopper Pogo Exercise Balance Ball ...
#
#                                             also_buy  \
# 0                                       [B072BH2LWS]
# 1  [B00BQ7ZNPS, B01395HG4U, B0197DBCYS, B0128U6JB...
# 2                                       [B010UZXUBK]
# 3                                       [B078K1T2RK]
# 4                                       [B00J4XLAV2]
#
#                                                image tech2  \
# 0  [https://images-na.ssl-images-amazon.com/image...
# 1  [https://images-na.ssl-images-amazon.com/image...
# 2                                                 []
# 3  [https://images-na.ssl-images-amazon.com/image...
# 4  [https://images-na.ssl-images-amazon.com/image...
#
#                  brand                                            feature  \
# 0  Green Blob Outdoors  [Green Blob Outdoors Tactical Micro Iron Sight...
# 1                  GPP  [Allows you to attach any spincast style reel ...
# 2                                                                      []
# 3             Flexzion  [The folding stool features durable cloth and ...
# 4                                                                      []
#
#                              rank  \
# 0   83,960 in Sports & Outdoors (
# 1  102,928 in Sports & Outdoors (
# 2  764,271 in Sports & Outdoors (
# 3   42,140 in Sports & Outdoors (
# 4  790,694 in Sports & Outdoors (
#
#                                            also_view  \
# 0  [B07D7J5GGF, B01AISP1KW, B077YHM95G, B071746KS...
# 1  [B071JH8N72, B0197DBCYS, B0153Z093E, B01395HG4...
# 2                                                 []
# 3  [B01BBX9NJS, B0015OYXY4, B07M8P8CPJ, B073XDCQ4...
# 4                                                 []
#
#                                              details           main_cat  \
# 0                           {'ASIN: ': 'B010UZ3LDW'}  Sports & Outdoors
# 1  {'
#     Item Weight:
#     ': '2.88 ounces', 'Sh...  Sports & Outdoors
# 2  {'
#     Product Dimensions:
#     ': '20 x 3 x 3...  Sports & Outdoors
# 3  {'
#     Product Dimensions:
#     ': '19.5 x 2.5...  Sports & Outdoors
# 4                           {'ASIN: ': 'B010V0USHS'}  Sports & Outdoors
#
#                                         similar_item date   price        asin
# 0   class="a-bordered a-horizontal-stripes  a-spa...       $19.95  B010UZ3LDW
# 1                                                          $12.99  B010UZPA68
# 2                                                                  B010UZY5ZK
# 3                                                          $13.95  B010UZXUBK
# 4                                                                  B010V0USHS

# %%
import json
import pandas as pd
from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import os

# Function to clean text
def clean_text(text):
    # Remove HTML tags
    text = BeautifulSoup(text, "html.parser").get_text()
    # Remove non-alphanumeric characters and convert to lowercase
    text = re.sub(r'[^a-zA-Z\s]', '', text).lower()
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    # Join tokens back into a string
    clean_text = ' '.join(tokens)
    return clean_text

# Function to preprocess data
def preprocess_data(df):
    # Ensure 'description' column contains strings
    df['description'] = df['description'].astype(str)
    
    # Clean 'description' column
    df['description'] = df['description'].apply(clean_text)
    
    # Convert 'price' column to numerical
    df['price'] = df['price'].str.extract(r'\b(\d+\.\d+)\b').astype(float)
    
    # Extract main category from 'category' column
    df['main_category'] = df['category'].apply(lambda x: x[0])
    
    # Drop irrelevant columns
    df.drop(['tech1', 'tech2', 'details', 'similar_item', 'category'], axis=1, inplace=True)
    
    return df



# Load Sampled Amazon dataset
df_chunks = pd.read_json('Sampled_Amazon_Meta.json', lines=True, chunksize=10000)

# Preprocess and write to a new JSON file
output_file = 'preprocessed_amazon_data.json'
with open(output_file, 'w') as f:
    for i, df_chunk in enumerate(df_chunks):
        preprocessed_df_chunk = preprocess_data(df_chunk)
        preprocessed_df_chunk.to_json(f, orient='records', lines=True)
        print(f"Processed chunk {i+1}")

print("Preprocessing complete.")

# Bonus: Perform batch processing in real-time
# Monitor a directory for new files and preprocess them as they arrive
input_directory = 'incoming_data'
output_directory = 'preprocessed_data'
os.makedirs(output_directory, exist_ok=True)

while True:
    # Check for new files in the input directory
    files = os.listdir(input_directory)
    for file in files:
        if file.endswith('.json'):
            input_file = os.path.join(input_directory, file)
            output_file = os.path.join(output_directory, file)
            df = pd.read_json(input_file, lines=True)
            preprocessed_df = preprocess_data(df)
            preprocessed_df.to_json(output_file, orient='records', lines=True)
            print(f"Preprocessed file {file} and saved as {output_file}")
            os.remove(input_file)  # Remove the processed file from the input directory
    time.sleep(60)  # Check for new files every 60 seconds
# Out:
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 1
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 2
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 3
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 4
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 5
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 6
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 7
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 8
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 9
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 10
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 11
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 12
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 13
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 14
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 15
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 16
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 17
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 18
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 19
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 20
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 21
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 22
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 23
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 24
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 25
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 26
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 27
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 28
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 29
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 30
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 31
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 32
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 33
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 34
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 35
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 36
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 37
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 38
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 39
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 40
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 41
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 42
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 43
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 44
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 45
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 46
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 47
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 48
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 49
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 50
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 51
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 52
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 53
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 54
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 55
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 56
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 57
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 58
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 59
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 60
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 61
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 62
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 63
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Processed chunk 64
# C:\Users\Irtaza Malik\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15736\311922609.py in <module>
#      50 with open(output_file, 'w') as f:
#      51     for i, df_chunk in enumerate(df_chunks):
# ---> 52         preprocessed_df_chunk = preprocess_data(df_chunk)
#      53         preprocessed_df_chunk.to_json(f, orient='records', lines=True)
#      54         print(f"Processed chunk {i+1}")
#
# ~\AppData\Local\Temp\ipykernel_15736\311922609.py in preprocess_data(df)
#      34
#      35     # Extract main category from 'category' column
# ---> 36     df['main_category'] = df['category'].apply(lambda x: x[0])
#      37
#      38     # Drop irrelevant columns
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# -> 1143                 mapped = lib.map_infer(
#    1144                     values,
#    1145                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp\ipykernel_15736\311922609.py in <lambda>(x)
#      34
#      35     # Extract main category from 'category' column
# ---> 36     df['main_category'] = df['category'].apply(lambda x: x[0])
#      37
#      38     # Drop irrelevant columns
#
# IndexError: list index out of range
